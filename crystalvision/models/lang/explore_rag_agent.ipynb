# %%
#!playwright install
#!playwright install-deps

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain.document_loaders import AsyncChromiumLoader
import json
import asyncio
import logging
from typing import AsyncIterator, Iterator, List, Optional

from langchain_core.documents import Document

import os
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"

import nest_asyncio
nest_asyncio.apply()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
# loader = WebBaseLoader("https://materiahunter.com/faq")
# loader = AsyncChromiumLoader(["https://materiahunter.com/faq"])


urls = [
    f"https://m2pote0hr6y7aw8dp.a1.typesense.net/collections/rules/documents/search?q=*&limit=250&page={i}&facet_by=serials,tags&query_by=serials,+tags,+title,+body" for i in range(1, 5)
]
extra_http_headers = {
    "x-typesense-api-key": "0RbWmbctto4gEdrHVPeF8ltS1Bv16yyJ"
}

class MyACLoader(AsyncChromiumLoader):
    async def ascrape_playwright(self, url: str) -> str:
        """
        Asynchronously scrape the content of a given URL using Playwright's async API.

        Args:
            url (str): The URL to scrape.

        Returns:
            str: The scraped HTML content or an error message if an exception occurs.

        """
        from playwright.async_api import async_playwright

        # logger.info("Starting scraping...")
        results = ""
        async with async_playwright() as p:
            browser = await p.chromium.launch(headless=self.headless)
            try:
                page = await browser.new_page(user_agent=self.user_agent, extra_http_headers=extra_http_headers)
                await page.goto(url)
                results = await page.content()  # Simply get the HTML content
                # logger.info("Content scraped")
                a_handle = await page.evaluate_handle("document.body")
                result_handle = await page.evaluate_handle("body => body.querySelector('pre').innerHTML", a_handle)
                results = await result_handle.json_value()
                await result_handle.dispose()
            except Exception as e:
                results = f"Error: {e}"
            await browser.close()
        return json.loads(results)["hits"]

    def lazy_load(self) -> Iterator[Document]:
        """
        Lazily load text content from the provided URLs.

        This method yields Documents one at a time as they're scraped,
        instead of waiting to scrape all URLs before returning.

        Yields:
            Document: The scraped content encapsulated within a Document object.

        """
        for url in self.urls:
            html_content = asyncio.run(self.ascrape_playwright(url))
            # metadata = {"source": url}
            for content in html_content:
                content = content["document"]
                metadata = {
                    "title": content['title'],
                    "source": content['source']
                }
                yield Document(page_content=f"In reference to the card {content['title']}: {content['body']}", metadata=metadata)


loader = MyACLoader(urls)

docs = loader.load()
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
docs
# Out:
# [Document(metadata={'title': '[23-080R] Odin', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-080R] Odin: It is not possible to remove the Lightning element card discarded to pay the cost for this ability from the game.'),
#  Document(metadata={'title': '[23-081C] Puppetmaster', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-081C] Puppetmaster: - You still need to select a Forward card, even if you control five or more Backup cards.\n\n- The ability’s effects are rendered invalid if the Forward selected is no longer a valid target,  due to having moved away from the field by the point when effects are resolved etc., even if you control five or more Backup cards.'),
#  Document(metadata={'title': '[23-082H] King', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-082H] King: - When using this ability, it is not possible to remove the character cards that were discarded to pay the cost for casting it.\n\n- This auto-ability causes cards to be discarded from the player’s hand at the point when effects are resolved. The auto ability to select one Forward and break it is then added to the stack after the cards are discarded.'),
#  Document(metadata={'title': '[23-084C] G’raha Tia', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-084C] G’raha Tia: A G’raha Tia card in the Break Zone is removed from the game at the point when effects are resolved. The auto ability to select two Forwards controlled by the opponent and inflict 4000 damage to them is then added to the stack after the card is removed.'),
#  Document(metadata={'title': '[23-088L] Serah', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-088L] Serah: - It is possible to replace this card’s power value with a specific number using the effects from other cards such as 6-052R Diablos. In this situation, the change to the power value is not treated as a “+” modifier.\n\n- When “dispel” is used, all “+” modifiers to power values from field abilities cease to apply.\n\n- If action abilities, auto abilities or Summons that increase power values have already been resolved and “dispel” is used after that resolution, the power increase will still remain in effect but any abilities or Summons used to increase power after that will not take effect'),
#  Document(metadata={'title': '[23-092R] Black Widow', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-092R] Black Widow: The Monster card is placed in the Break Zone at the point when effects are resolved. The auto ability to select one Forward and inflict 9000 damage on it is then added to the stack after the card is placed in the Break Zone.'),
#  Document(metadata={'title': '[23-094C] Y’shtola', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-094C] Y’shtola: The effect of this card’s ability is still resolved, even if the player controls fewer job: “Scion of the Seventh Dawn” cards than the number of Forwards selected at the point when effects are resolved.'),
#  Document(metadata={'title': '[23-101C] Dancer', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-101C] Dancer: - You still need to select a Forward card, even if you control five or more Backup cards.\n\n- The ability’s effects are rendered invalid if the Forward selected is no longer a valid target,  due to having moved away from the field by the point when effects are resolved etc., even if you control five or more Backup cards.'),
#  Document(metadata={'title': '[23-107L] Frimelda', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-107L] Frimelda: The effect of this card’s ability is still resolved, even if the number of different elements possessed by characters under the player’s control has fallen to three or lower after the effect is selected.'),
#  Document(metadata={'title': '[23-108R] Fourchenault', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-108R] Fourchenault: If the player controls both a Card Name: “Alisaie” and a Card Name: “Alphinaud” card, the cost to cast Fourchenault becomes 0.'),
#  Document(metadata={'title': '[23-129H] Lunafreya', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-129H] Lunafreya: - It is possible to interrupt an EX Burst effect that is triggered by this card with a Summon or ability.\n\n- An EX Burst effect triggered by this card is neither an auto-ability nor a Summon. Accordingly, it is not possible to render it invalid using cards such as 5-068L Y’shtola.\n\n- An EX Burst effect triggered by this card does possesses “auto-ability” and/or “Summon” information. Accordingly, it is not possible to select a character that has the “is not selected by Summons and abilities” trait with that effect.'),
#  Document(metadata={'title': '[23-117L] Chaos', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-117L] Chaos: - Cards are removed from the Break Zone at the point when effects are resolved. The auto ability to make the opponent select one Forward controlled by the player and place it in the Break Zone, then discard two cards from their hand, is then added to the stack after the cards have been removed.\n\n- Putting 10 cards from your deck into the Break Zone is treated as paying cost, so the special ability cannot be used if there are 9 or fewer cards in the deck.'),
#  Document(metadata={'title': '[23-115L] Venat', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-115L] Venat: The Crystal is paid at the point when effects are resolved. The auto ability to select one Forward and remove it from the game is then added to the stack after payment is made.'),
#  Document(metadata={'title': '[23-124L] Eiko', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-124L] Eiko: If a Summon that was searched for is not cast, that Summon remains removed from the game.'),
#  Document(metadata={'title': '[23-069C] Narasimha', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-069C] Narasimha: - The source of damage is the Forward you control that was chosen.\n\n- If the Forward under your control that was chosen has left the field at the point when this auto ability is resolved, it will not inflict damage to the Forward under the opponent’s control that was chosen.'),
#  Document(metadata={'title': '[23-068C] SOLDIER Candidate', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-068C] SOLDIER Candidate: Forward cards left in the field will not take damage if the SOLDIER Candidate or the Forward card chosen has left the field at the point when this auto ability is resolved.'),
#  Document(metadata={'title': '[23-067R] Shantotto', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-067R] Shantotto: - Two Summons must be selected. If only one Summon is present in the Break Zone, it is not possible to select it.\n\n- It is possible to select one of your own Summons and one of the opponent’s Summons to make up the required two.'),
#  Document(metadata={'title': '[23-065R] Gogmagog', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-065R] Gogmagog: The monster card is removed from the game at the point when effects are resolved. The auto ability to play Gogmagog to the field from the Break Zone is then added to the stack after the monster is removed.'),
#  Document(metadata={'title': '[23-064R] Golem', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-064R] Golem: It is not possible to cast Golem if there are no Forwards present in the field that can be selected.'),
#  Document(metadata={'title': '[23-061H] Warrior of Light', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-061H] Warrior of Light: CP are paid at the point when effects are resolved. The auto ability to search for a cost: “X”, job: “Standard Unit” character card and play it to the field is then added to the stack after payment is made.'),
#  Document(metadata={'title': '[23-058C] Dark Knight', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-058C] Dark Knight: - You still need to select a Forward card, even if you control five or more Backup cards.\n\n- The ability’s effects are rendered invalid if the Forward selected is no longer a valid target,  due to having moved away from the field by the point when effects are resolved etc., even if you control five or more Backup cards.'),
#  Document(metadata={'title': '[23-051L] Hope', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-051L] Hope: CP are paid at the point when effects are resolved. The auto ability to search for a cost: “X”, category: “XIII” character card and play it to the field is then added to the stack after payment is made.'),
#  Document(metadata={'title': '[23-049C] Ninja', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-049C] Ninja: - You still need to select a Forward card, even if you control five or more Backup cards.\n\n- The ability’s effects are rendered invalid if the Forward selected is no longer a valid target,  due to having moved away from the field by the point when effects are resolved etc., even if you control five or more Backup cards.'),
#  Document(metadata={'title': '[23-047H] Tyro', 'source': 'https://fftcg.square-enix-games.com/en/play-article/faq'}, page_content='In reference to the card [23-047H] Tyro: The elements the player controls have to be exactly three different types. It is not possible to add the selected card to your hand if the characters you control have four or more different elements.'),
#  Document(metadata={'title': '[23-038H] Lady Lilith', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-038H] Lady Lilith: The Crystal is paid at the point when effects are resolved. The auto ability to select one Forward and gain control of it is then added to the stack after payment is made.'),
#  Document(metadata={'title': '[23-036C] Flan', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-036C] Flan: This card can be included in the three job: “Flan” cards that are removed from the game to pay the cost for the second action ability.'),
#  Document(metadata={'title': '[23-030C] Serah', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-030C] Serah: - The upgraded effect to select two cards will be still be resolved, even if the player’s job: “commando” card leaves the field before effects are resolved\n\n- If the second action is selected and the character chosen as the target subsequently becomes an ineligible target due to leaving the field before effects are resolved or by some other means, the opponent does not discard a card from their hand.'),
#  Document(metadata={'title': '[23-029R] Zenos', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-029R] Zenos: - The second auto ability can only be activated once, even if two or more cards in the Break Zone are removed from the game.\n\n- Zenos auto abilities will also trigger when an LB character moves to an LB deck from the Break Zone due to the LB rules.'),
#  Document(metadata={'title': '[23-028L] Cecil', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-028L] Cecil: The point of damage is taken at the point when effects are resolved. The auto ability to select two characters, dull and freeze them, is then added to the stack after the damage is taken.'),
#  Document(metadata={'title': '[23-022R] Aemo', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-022R] Aemo: A player using Aemo’s action ability cannot look at the opponent’s cards which are turned face own.'),
#  Document(metadata={'title': '[23-021C] Weiss', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-021C] Weiss: The Crystal is paid at the point when effects are resolved. The auto ability to search for a single job: Tsviets card and add it to the player’s hand is then added to the stack after payment is made.'),
#  Document(metadata={'title': '[23-119R] Vincent', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-119R] Vincent: The Backup card is placed in the Break Zone at the point when effects are resolved. The auto ability to select a Forward that the opponent controls and inflict 9000 damage on it is then added to the stack after the Backup card is placed in the Break Zone.'),
#  Document(metadata={'title': '[23-118H] Ardyn', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-118H] Ardyn: It is possible to use Ardyn’s auto ability to play a card from the player’s LB deck to the field, even if there are no face down cards in the LB deck to turn face up.'),
#  Document(metadata={'title': '[23-017C] Parai', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-017C] Parai: The point of damage is taken at the point when effects are resolved. The auto ability to search for one category “FFL” character card and add it to the player’s hand is then added to the stack after the damage is taken.'),
#  Document(metadata={'title': '[23-008H] Zidane', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-008H] Zidane: It is not possible to only search for a single card.'),
#  Document(metadata={'title': '[23-006R] Soulcage', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-006R] Soulcage: Soulcage is removed from the game at the point when effects are resolved. The auto ability for the player to select one monster card from their own Break Zone and add it to their hand is then added to the stack after Soulcage is removed.'),
#  Document(metadata={'title': '[23-003C] Kain', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-003C] Kain: The power increase for Forward cards that have both Haste and First Strike is still only +2000.'),
#  Document(metadata={'title': '[23-002L] Caius', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card [23-002L] Caius: - The next time a Bahamut card is cast, the cost will be reduced by 5, even if the player has not chosen to search for Bahamut first.\n\n- Cards from the player’s hand are discarded at the point when effects are resolved. The auto ability to remove Caius from the Break Zone and play him on the field in the dull state is then added to the stack after the cards are discarded.'),
#  Document(metadata={'title': 'If an ability inflicts damage to several Forwards, is the damage dealt to all of them at the same time?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card If an ability inflicts damage to several Forwards, is the damage dealt to all of them at the same time?: Yes, Forwards receive the damage at the same time. Any bonus granted by a Forward to another Forward doesn't apply anymore if the former is broken at the same time.\n\ne.g. My opponent controls Rikku 1-201S as well as 1-214S Yuna meaning Rikku gains +2000 power and has now 8000 (If you control [Card Name (Yuna)], Rikku gains +2000 power and Rikku cannot be chosen by Summons.)\n\nIf I cast 1-191S Red XIII's Cosmo Memory “Deal 6000 damage to all the Forwards opponent controls.”, Yuna is broken so Rikku loses 2000 power falling back to 6000 and is thus broken by RED-XIII's special ability."),
#  Document(metadata={'title': '5-106R - Black Knight', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-106R - Black Knight: If 2 or more Forwards of cost 4 or less enter the field simultaneously, Black Knight's auto-ability is triggered for each of them. You can stack the abilities in your preferred order, but as you cannot break the Forward with Black Knight's auto-ability unless you put Black Knight into the Break Zone, you can only break 1 Forward.\n\nIf using a card like 1-176H - Yuna, with which Black Knight can be removed from the game instead of put into the Break Zone, it can still break a Forward.\n\nIf on the other hand Black Knight is removed from the field before its auto-ability resolves, it can't be put into the Break Zone and therefore cannot break any Forwards."),
#  Document(metadata={'title': 'If I attack with a Forward, my opponent declares a blocker and I then use a Summon to destroy that blocker before the damage is exchanged, does my opponent take 1 point of damage or does he have a chance to choose another blocker?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card If I attack with a Forward, my opponent declares a blocker and I then use a Summon to destroy that blocker before the damage is exchanged, does my opponent take 1 point of damage or does he have a chance to choose another blocker?: Neither of the two. A blocker was already declared meaning that the block will be successful regardless if the blocking Forward is destroyed, your opponent won't receive any point of damage. It is not possible for him to choose another blocker either as there can be only one Forward blocking another and the block was successful. So in this case, the blocking forward is destroyed and no damage exchanged at all."),
#  Document(metadata={'title': 'If I attack with a Party and the blocker has First Strike, how is the damage exchanged?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card If I attack with a Party and the blocker has First Strike, how is the damage exchanged?: e.g. if you have a party made up of two 5000 power Forwards and your opponents blocks with a 5000 power Forward that has first strike, he will inflict 5000 damage first and can break one of the two Forwards in your Party (if he chooses to allocate the full 5000 on 1 Forward). Then, your other Forward will deal 5000 damage to his and break it. Result: 1 of the two Forwards forming your Party will survive.'),
#  Document(metadata={'title': 'Can I use First Strike when attacking with a party?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card Can I use First Strike when attacking with a party?: You can only benefit from First Strike if all members of your party have this trait. Other abilities and traits like Brave work on an individual level (e.g. if a Forward in the Party has Brave, he doesn't dull when attacking)."),
#  Document(metadata={'title': 'How does Freeze work exactly?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card How does Freeze work exactly?: If any of the dull Characters you control gets Frozen, it simply won't activate during your next Active Phase. You can use an ability like 1-200S Baralai's to activate the Character before this Phase but bear in mind that the Freeze effect will still remain. If the frozen Character gets dull again before your next Active Phase, it will not activate then."),
#  Document(metadata={'title': 'After attacking with a Forward, can I use a Summon like 1-074R Sylph while still during my Attack Phase to re-activate that Forward and attack again?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card After attacking with a Forward, can I use a Summon like 1-074R Sylph while still during my Attack Phase to re-activate that Forward and attack again?: No. Forwards can only attack once per turn.'),
#  Document(metadata={'title': "What do card categories like 1-182L Cloud's “DFF·VII” stand for?", 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card What do card categories like 1-182L Cloud's “DFF·VII” stand for?: These are actually two distinct categories. “DFF·VII” means that the card is of both Dissidia Final Fantasy and Final Fantasy VII. For example, when you are using a card ability like 1-204S Jessie's: “When Jessie enters the field, you may search for 1 [(Category (VII)] Forward and add it to your hand.”, you can actually add 1-182L Cloud to your hand as his category is DFF·VII."),
#  Document(metadata={'title': 'I discarded 2 cards to play a Forward of cost 3, can I use the extra Crystal Point left towards another cost?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card I discarded 2 cards to play a Forward of cost 3, can I use the extra Crystal Point left towards another cost?: No, any extra CP generated is lost, this is also why Backups are important to top up when the cost of the card you want to play is an odd number. CPs are always generated towards a single use/cost, there will be one exception called “Overdrive” in the future but none of the cards in Opus I have this ability yet.'),
#  Document(metadata={'title': 'When a Backup ability requires to dull it, does doing so also generate 1 Crystal Point?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card When a Backup ability requires to dull it, does doing so also generate 1 Crystal Point?: No. For example, if a Backup ability requires you to pay 1 Crystal Point and dull that Backup as part of the cost, the CP must be generated by dulling a different Backup or discarding a card from your hand. Dulling a Backup as part of its ability's cost and dulling a Backup to generate 1 Crystal Point are two different actions you have to choose from."),
#  Document(metadata={'title': 'If I already control 5 Backups, how can I play another one onto the field?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card If I already control 5 Backups, how can I play another one onto the field?: You can only have 5 Backups on your field at a given time but there are some abilities that can break Backups or return them to your hand in order to play different ones. Certain Backups like 1-120C Monk also need to be put into the Break Zone as part of their ability's cost so this is another way to free up some space on your field while using certain abilities."),
#  Document(metadata={'title': 'Is there a limit to the number of cards I can discard from my hand?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card Is there a limit to the number of cards I can discard from my hand?: No. You can discard as many cards as you like, during your turn to play Characters or use Summons &amp; abilities and during your opponent's turn to play Summons and abilities. Starting with an empty hand might not be the best strategy though!"),
#  Document(metadata={'title': 'Is there a limit to the number of Forwards in a Party?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card Is there a limit to the number of Forwards in a Party?: No.'),
#  Document(metadata={'title': 'Is there a limit to the number of Forwards I can play onto the field?', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card Is there a limit to the number of Forwards I can play onto the field?: No.'),
#  Document(metadata={'title': "5-148H - Kam'lanaut", 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-148H - Kam'lanaut: Kam'lanaut's Element switching ability overwrites his current Element. (He ceases to have that Element.) You can select the same Element that he already has again."),
#  Document(metadata={'title': "5-147L - Eald'narche", 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-147L - Eald'narche: If the game ends by the end of the turn in which “Paradise” is played, the self-defeat ability of “Paradise” doesn't occur. However, if you take damage or become unable to draw from your deck, you lose the game as usual.\n\nIf “Paradise” is played again in the additional turn gained by playing “Paradise,” you still lose at the end of the original additional turn."),
#  Document(metadata={'title': '5-145L - Vaan', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-145L - Vaan: Actions are selected when the auto-ability activates.\n\nActions are performed in the order they're written, from top to bottom."),
#  Document(metadata={'title': '5-141H - Refia', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-141H - Refia: If a Forward is both of Water Element and Job Warrior of Light, it still only gains +1000 power.'),
#  Document(metadata={'title': '5-139C - Leviathan', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-139C - Leviathan: The number of cards in your hand is calculated when the ability resolves.'),
#  Document(metadata={'title': '5-137C - Green Mage', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-137C - Green Mage: Green Mage's action ability can only choose action abilities that are on the stack."),
#  Document(metadata={'title': '5-133H - Bismarck', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-133H - Bismarck: Actions are selected when summoning.\n\nActions are performed in the order they're written, from top to bottom."),
#  Document(metadata={'title': '5-135L - Porom', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-135L - Porom: Porom's action ability can only choose action abilities that are on the stack."),
#  Document(metadata={'title': '5-130R - Tonberry', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-130R - Tonberry: If using a card like1-176H - Yuna, with which Tonberry can be removed from the game instead of put into the Break Zone, Tonberry can still break the Character.\n\nIf on the other hand Tonberry is removed from the field before its auto-ability resolves, it can't be put into the Break Zone and therefore cannot break the Character."),
#  Document(metadata={'title': '5-100H - Odin', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-100H - Odin: Actions are selected when casting.\n\nActions are performed in the order they're written, from top to bottom."),
#  Document(metadata={'title': '5-099H - Illua', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-099H - Illua: Illua's auto-ability is triggered only when she is first chosen in that turn. Following that, it isn't triggered even if she's chosen again."),
#  Document(metadata={'title': '5-090R - Hill Gigas', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-090R - Hill Gigas: If using a card like 1-176H - Yuna, with which Hill Gigas can be removed from the game instead of put into the Break Zone, Hill Gigas can still cancel the effect and break the Character.\n\nIf on the other hand Hill Gigas is removed from the field before its auto-ability resolves, it can't be put into the Break Zone and therefore cannot cancel the effect or break the Character."),
#  Document(metadata={'title': '5-086L - Cecil', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-086L - Cecil: If the damage dealt by the special ability “Dark” causes the EX BURST to occur, the effects of the EX BURST resolve after the effects of “Dark.”'),
#  Document(metadata={'title': '5-081C - Cockatrice', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-081C - Cockatrice: If selecting a Forward in the midst of attacking or blocking, that attack or block does not become invalidated.'),
#  Document(metadata={'title': '5-079H - Calbrena', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-079H - Calbrena: Once Calbrena returns to the field, it is no longer a Forward.'),
#  Document(metadata={'title': '5-078R - Gabranth', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-078R - Gabranth: Even if receiving 2 or more damage at once, that damage becomes 0.'),
#  Document(metadata={'title': '5-075L - Wol', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-075L - Wol: Actions are selected when the auto-ability activates.\n\nActions are performed in the order they're written, from top to bottom."),
#  Document(metadata={'title': '5-074H - Ingus', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-074H - Ingus: If a Forward is both of Earth Element and Job Warrior of Light, it still only gains +1000 power.'),
#  Document(metadata={'title': '5-071R - Leyak', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-071R - Leyak: If using a card like1-176H - Yuna, with which Leyak can be removed from the game instead of put into the Break Zone, Leyak can still activate the Characters you control and make you draw 1 card.\n\nIf on the other hand Leyak is removed from the field before its auto-ability resolves, it can't be put into the Break Zone and therefore cannot activate the Characters you control and make you draw 1 card."),
#  Document(metadata={'title': '5-062L - Diabolos', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-062L - Diabolos: Actions are selected when casting.\n\nActions are performed in the order they're written, from top to bottom."),
#  Document(metadata={'title': '5-060C - Chocobo', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-060C - Chocobo: If Chocobo ceases to be in a party due to an effect occurring during an attack, it takes damage.'),
#  Document(metadata={'title': '5-053R - Echo', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-053R - Echo: Actions are selected when the auto-ability activates.\n\nActions are performed in the order they're written, from top to bottom."),
#  Document(metadata={'title': '5-052H - Arc', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-052H - Arc: If a Forward is both Wind and Job Warrior of Light, it still only gains +1000 power.'),
#  Document(metadata={'title': '5-049C - Asura', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-049C - Asura: ”Negate all damage dealt to it” means all damage that the Forward has received since the beginning of the current turn.'),
#  Document(metadata={'title': '5-048H - Lugae', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-048H - Lugae: The choice between Dull and Freeze is made when the ability resolves.'),
#  Document(metadata={'title': '5-046R - Buccaboo', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-046R - Buccaboo: If 2 or more Characters enter the field simultaneously, Buccaboo's auto-ability is triggered for each of them. You can stack the abilities in your preferred order, but as you cannot force your opponent to discard with Buccaboo's auto-ability unless you put Buccaboo into the Break Zone, you can only force your opponent to discard once.\n\nIf using a card like1-176H - Yuna, with which Buccaboo can be removed from the game instead of put into the Break Zone, Buccaboo can still make your opponent discard 2 cards.\n\nIf on the other hand Buccaboo is removed from the field before its auto-ability resolves, it can't be put into the Break Zone and therefore cannot make your opponent discard 2 cards."),
#  Document(metadata={'title': '5-042C - Trickster', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-042C - Trickster: This doesn't apply just for attack or block. Trickster doesn't receive any damage from cards like 4-093R - Hecatoncheir either."),
#  Document(metadata={'title': '5-041R - Snow', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-041R - Snow: X is paid when the ability resolves.'),
#  Document(metadata={'title': '5-037R - Zeid', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-037R - Zeid: Even if Zeid is attacked simultaneously by multiple Forwards during a party attack, only 1 card is discarded. (A party is considered as 1 Character.)'),
#  Document(metadata={'title': '5-036L - The Emperor', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-036L - The Emperor: If your opponent draws two or more cards, the auto-ability is triggered for each card drawn.'),
#  Document(metadata={'title': '5-032H - Glasya Labolas', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-032H - Glasya Labolas: Actions are selected when casting.\n\nActions are performed in the order they're written, from top to bottom."),
#  Document(metadata={'title': '5-028C - Arcanist', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-028C - Arcanist: The number is selected when the ability resolves.'),
#  Document(metadata={'title': '5-149S - Amodar', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-149S - Amodar: ”Double the power of Amodar” means his current power plus any adjustments. For example, if he has had +1000 power added by using【1-030R】 Lebreau, then his power would go up +9000.'),
#  Document(metadata={'title': '5-024H - Luneth', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-024H - Luneth: If a Forward is both Fire Element and Job Warrior of Light, it still only gains +1000 power.'),
#  Document(metadata={'title': '5-019L - Phoenix', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-019L - Phoenix: If you don't have any Forwards of cost 3 or less in your Break Zone, Phoenix cannot be cast."),
#  Document(metadata={'title': '5-015H - Tellah', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-015H - Tellah: ”Recall” Special ability - The top card of your deck is removed when the ability resolves.'),
#  Document(metadata={'title': "5-011H - Vermillion Bird l'Cie Zhuyu", 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-011H - Vermillion Bird l'Cie Zhuyu: The number of times Vermillion Bird l'Cie Zhuyu can attack this turn increases by one each time a Forward damaged by it is put into the Break Zone."),
#  Document(metadata={'title': '5-008R - Grenade', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-008R - Grenade: If 2 or more Forwards with less than 8000 power enter the field at the same time, Grenade's auto-ability is triggered for each of them. You can stack the abilities in your preferred order, but as you cannot deal damage with Grenade's ability unless you put Grenade into the Break Zone, you can only do 8000 damage once.\n\nIf using a card like 1-176H - Yuna, with which Grenade can be removed from the game instead of put into the Break Zone, Grenade can still deal the 8000 damage.\n\nIf on the other hand Grenade is removed from the field before its auto-ability resolves, it can't be put into the Break Zone and therefore cannot deal the 8000 damage."),
#  Document(metadata={'title': '5-003C - Ifrit', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 5-003C - Ifrit: The choice to discard 1 “Card Name Ifrit” happens when the ability resolves.'),
#  Document(metadata={'title': '6-130L - Nidhogg', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-130L - Nidhogg: Your opponent must have their cards face-down and shuffled so that they do not know which is which when removing a card. The removed card is placed face-up.'),
#  Document(metadata={'title': '6-127L - Hraesvelgr', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-127L - Hraesvelgr: If the Attack Phase is skipped, Main Phase 2 begins immediately after Main Phase 1. Auto-abilities that include "At the start of the Attack Phase" are not triggered.'),
#  Document(metadata={'title': '6-124L - Yuna', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-124L - Yuna: The decision of whether to play the Forward from your hand onto the field or search for the Forward occurs when resolving.'),
#  Document(metadata={'title': '6-112H - Shuyin', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-112H - Shuyin: Unless the Forward you have gained control of has Haste, it may not attack or use any abilities with the dull icon this turn.\n\nEven if control has changed, the card keeps the same status. For example, if it\'s dulled is stays dulled, and effects such as "Add +1000 power until the end of the turn" stay in effect.'),
#  Document(metadata={'title': '6-110C/1-159C - Evoker', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-110C/1-159C - Evoker: This card is the same as1-159C - Evoker. You may not have more then three of these cards in your deck.'),
#  Document(metadata={'title': '6-096C/1-138C - Summoner', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-096C/1-138C - Summoner: This card is the same as1-138C - Summoner. You may not have more then three of these cards in your deck.'),
#  Document(metadata={'title': '6-101R - Raijin', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-101R - Raijin: When resolving this special ability, is still resolves even if you have lost control of Card Name Seifer or Card Name Fujin.'),
#  Document(metadata={'title': '6-099H - Frimelda', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-099H - Frimelda: The number of Job Sword Saint is calculated during resolution.'),
#  Document(metadata={'title': '6-041L - Rinoa', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-041L - Rinoa: A Forward removed from and then played back on to the field is treated as a newly played Forward. Unless it has Haste, it may not attack or use any abilities with the dull icon this turn. All temporary power modifiers and all damage is removed.'),
#  Document(metadata={'title': '6-094L - Seifer', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 6-094L - Seifer: Seifer's auto-ability is triggered when he blocks or is blocked. This occurs before damage resolution."),
#  Document(metadata={'title': '6-092C - Quezacotl', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-092C - Quezacotl: Cannot be cast or used as an Ex Burst unless 2 Forwards are chosen.'),
#  Document(metadata={'title': '6-090H - Kain', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-090H - Kain: When your opponent gains control of Kain, unless he has Haste, he may not attack during that turn.\n\nEven if control has changed, the card keeps the same status. For example, if Kain is dulled he stays dulled, and effects such as "Add +1000 power until the end of turn" stay in effect.'),
#  Document(metadata={'title': '6-088L - Estinien', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-088L - Estinien: The Forward blocking Estinien is broken during the Block Declaration step. They do not damage each other.'),
#  Document(metadata={'title': '6-087R - Edea', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-087R - Edea: You cannot choose this card from the Break Zone.'),
#  Document(metadata={'title': '6-084L - Leo', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-084L - Leo: Backups can produce CP of any Element, but they do not become that Element. Their Element remains as it is on the card.'),
#  Document(metadata={'title': "6-083H - Y'shtola", 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-083H - Y\'shtola: The first ability keeps Y\'shtola from being broken by summons or abilities such as1-124R - Odin\'s "Choose 1 Forward. Break it." If Y\'shtola takes more then her power level in damage from a summon or an ability, she breaks as per normal rules.'),
#  Document(metadata={'title': '6-075R - Titan', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-075R - Titan: Cannot be cast or used as an Ex Burst unless 2 Forwards are chosen.'),
#  Document(metadata={'title': '6-073C/1-105C - Evoker', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-073C/1-105C - Evoker: This card is the same as 1-105C - Evoker. You may not have more then three of these cards in your deck.'),
#  Document(metadata={'title': '5-071R - Leyak', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 5-071R - Leyak: If using a card like1-176H - Yuna, with which Leyak can be removed from the game instead of put into the Break Zone, Leyak can still activate the Characters you control and make you draw 1 card.\n\nIf on the other hand Leyak is removed from the field before its auto-ability resolves, it can't be put into the Break Zone and therefore cannot activate the Characters you control and make you draw 1 card."),
#  Document(metadata={'title': '6-063H - Leon', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-063H - Leon: When your opponent gains control of Leon, unless he has Haste, he may not attack during that turn.\n\nEven if control has changed, the card keeps the same status. For example, if Leon is dulled he stays dulled, and effects such as "Add +1000 power until the end of the turn" stay in effect.'),
#  Document(metadata={'title': '6-062R - Rikku', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-062R - Rikku: "When Rikku is in Battle" refers to when Rikku is either blocking or being blocked. She is not considered to be "in Battle" when her attack is not being blocked by your opponent\'s Forwards.\n\n"Remove Rikku from the battle" means that Rikku will no longer be attacking or blocking. If Rikku is removed from the Battle, Rikku and the Forward attacking her will do no damage to each other.'),
#  Document(metadata={'title': '6-052R - Diablos', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 6-052R - Diablos: Diablos changes the Forward's base power (as displayed on the card) to 4000. All other card or ability effects that modify the power are applied after this has taken place."),
#  Document(metadata={'title': '6-044L - Zidane', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-044L - Zidane: This card has an Erratum. The second auto-ability allows "1 Wind Character" to be chosen, not any character.\n\nIf your opponent discard 2 or more cards, the auto-ability occurs the same number of times as the number of cards discarded.'),
#  Document(metadata={'title': '6-043C/1-068C - Evoker', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-043C/1-068C - Evoker: This card is the same as1-068C - Evoker. You may not have more then three of these cards in your deck.'),
#  Document(metadata={'title': '6-041L - Hades', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-041L - Hades: If the targeted Forward is not longer a legal target at the time of resolution, your opponent do not have to discard.'),
#  Document(metadata={'title': '6-037C - Shock Trooper', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-037C - Shock Trooper: The Forward chosen by Shock Trooper is broken during the Attack Declaration step. It is broken before a Forward can be chosen to block.'),
#  Document(metadata={'title': '6-033H - Squall', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-033H - Squall: If your opponent has 0 cards, you gain the effects of both abilities.'),
#  Document(metadata={'title': '6-032C/1-040C - Summoner', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-032C/1-040C - Summoner: This card is the same as 1-040C - Summoner. You may not have more than three of these cards in your deck.'),
#  Document(metadata={'title': '6-027L - Kuja', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 6-027L - Kuja: Only Backups you control can be placed in the Break Zone to pay cost.'),
# ...
#  Document(metadata={'title': '21-028H - Shiva', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 21-028H - Shiva: - Shiva will not return to the player's hand if she is an invalid target at the point when effects are resolved."),
#  Document(metadata={'title': '21-023L - Ultimecia', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 21-023L - Ultimecia: - Cards in the Break Zone are removed from the game at the point when effects are resolved. The Auto Ability “Select the same number of Characters as the number of cards that were removed then Dull and Freeze them. Finally discard one card from your opponent's hand” is then added to the stack after one or more cards have been removed.\n\n- The number of cards the opponent discards will always be only one, regardless of whether two or more cards from the Break Zone have been removed from the game."),
#  Document(metadata={'title': '21-013H - Feolthanos', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 21-013H - Feolthanos: - The first Auto Ability is still activated, even if Feolthanos has been removed from the Field by an EX Burst.'),
#  Document(metadata={'title': '21-005C - Black Mage', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 21-005C - Black Mage: - 《1》is paid at the point when effects are resolved. The Auto Ability “Obtain《C” is then added to the stack after payment has been made.'),
#  Document(metadata={'title': '21-004L - Cyan', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 21-004L - Cyan: - CP are paid at the point when effects are resolved. The Auto Ability “Obtain《C》for each 1 cost paid to X” is then added to the stack after the CP have been paid.'),
#  Document(metadata={'title': '21-001R - Ward', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 21-001R - Ward: - It is not possible to cast Ward using CP that are not of the fire element, even if an effect of some type would otherwise allow the card to be cast by paying CP of an element the player selects.'),
#  Document(metadata={'title': 'PR-158 - Snow &amp; Lightning', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card PR-158 - Snow &amp; Lightning: - This counts as [Card Name(Snow)] and [Card Name(Lightning)]. You cannot play Snow &amp; Lightning onto the field if you already control either Snow or Lightning.'),
#  Document(metadata={'title': '22-111L - Raegen', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-111L - Raegen: - If the removed card is Multi-Element, it is counted as a card with multiple elements.\n\n'),
#  Document(metadata={'title': '22-110L - Citra', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-110L - Citra: - The Summon is cast immediately after the second auto-ability is resolved.\n\n- If the effect of the Summon that you searched for requires to choose something and there are no suitable targets, the Summon that you searched for is not cast and will remain removed.\n\n- If the removed card is Multi-Element, it is counted as a card with multiple elements.'),
#  Document(metadata={'title': '22-109H - Eden', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-109H - Eden: - The amount of damage to deal to each Forward is decided when they are chosen.'),
#  Document(metadata={'title': '22-122L - Tidus', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-122L - Tidus: - CP is paid at resolution. After paying the cost, the selected effect is placed on the stack.\n\n- Even if the total number of Forwards and Backups becomes 7 or less after paying CP, the subsequent auto-ability is resolved appropriately.'),
#  Document(metadata={'title': '22-104R - Folka', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-104R - Folka: - It is possible for 2 or more Forwards to form a party and attack once.'),
#  Document(metadata={'title': '22-048H - Nanaa Mihgo', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-048H - Nanaa Mihgo: - The Summon that has been chosen is cast immediately after the auto-ability is resolved.\n\n- If the effect of the chosen Summon requires to choose something and there are no suitable targets, the chosen Summon is not cast.'),
#  Document(metadata={'title': '22-103C - Faris', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-103C - Faris: - The Forward is removed from the game at resolution. After removal, the auto-ability “your opponent selects 1 Forward they control. Put it into the Break Zone.” is placed on the stack.'),
#  Document(metadata={'title': '22-091C - Blue Mage', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-091C - Blue Mage: - The Monster is discarded at resolution. Once discarded, the auto-ability “draw 1 card.” is placed on the stack.'),
#  Document(metadata={'title': '22-090H - Lulu', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-090H - Lulu: - The Summons are removed from the game at resolution. After removal, the auto-ability “choose 1 Forward. Deal it 7000 damage.” is placed on the stack.'),
#  Document(metadata={'title': '22-087R - Raijin', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-087R - Raijin: - If Raijin leaves the Break Zone before the auto-ability is resolved, Raijin does not enter the field.'),
#  Document(metadata={'title': '22-037R - Alexander', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-037R - Alexander: - The source of the damage is not changed.'),
#  Document(metadata={'title': '22-084R - Fujin', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-084R - Fujin: - If Fujin leaves the Break Zone before the auto-ability is resolved, Fujin does not enter the field.'),
#  Document(metadata={'title': '22-079L - Seifer', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-079L - Seifer: - The cards from the deck are put into the Break Zone at resolution. After putting the cards into the Break Zone, the auto-ability “choose 1 Category VIII Forward other than Card Name Seifer in your Break Zone. Add it to your hand.” is placed on the stack.\n\n- Cards will be put into the Break Zone by the first auto-ability even if there are 1 or less cards left in the deck, however the subsequent auto-ability will not be triggered.'),
#  Document(metadata={'title': '22-034H - Medusa', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-034H - Medusa: - The abilities “If a Petrification Counter is placed on this Forward, this Forward cannot attack or block.” and “《5》: Remove all Petrification Counters from this Forward.” remain after Medusa leaves the field.'),
#  Document(metadata={'title': '22-022R - Quistis', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-022R - Quistis: - If the number of Category VIII Forwards you control changes before the auto-ability is resolved and becomes less than the number of characters you chose, you still Dull them. However, if the number of Category VIII Forwards you control becomes 2 or less before resolution, you do not Freeze the chosen Forwards.'),
#  Document(metadata={'title': '22-066C - Summoner', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-066C - Summoner: - CP is paid at resolution. After payment, the auto-ability “choose 1 Summon in your Break Zone. Add it to your hand.” is placed on the stack.\n\n- After the action ability is resolved, if the chosen Summon leaves the Break Zone before it is cast, it cannot be cast.'),
#  Document(metadata={'title': '22-061L - Gilgamesh', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-061L - Gilgamesh: - CP is paid at resolution. After payment, the auto-ability “choose 1 Forward or Monster. Break it.” is placed on the stack.'),
#  Document(metadata={'title': '22-077H - Garuda (III)', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-077H - Garuda (III): - The number is selected at resolution. After the number is confirmed, it is not possible to intercede before the 8000 damage is dealt.'),
#  Document(metadata={'title': '22-076R - Odin', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-076R - Odin: - Only a card of cost 3 or 4 can be chosen for both Forward and Monster.'),
#  Document(metadata={'title': '22-065R - Sieghard', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-065R - Sieghard: - The Backups are dulled when resolved. After dulling them, the auto-ability “choose 1 Forward of cost 6 or less in your Break Zone. Play it onto the field.” is placed on the stack.'),
#  Document(metadata={'title': '22-113L - Mont Leonis', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-113L - Mont Leonis: - If neither a Fire Forward of cost 3 or less or a Fire Forward of cost 5 or less cannot be chosen, the auto-ability is not placed on the stack.\n\n- If you control 4 or less Backups, you also do not put a Backup into the Break Zone.'),
#  Document(metadata={'title': '22-118H - Shantotto', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-118H - Shantotto: - CP is paid at resolution. After payment, the auto-ability “remove all the Forwards and Monsters other than Shantotto from the game.” is placed on the stack.'),
#  Document(metadata={'title': '22-070C - Ramza', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-070C - Ramza: - If both field abilities are applied, the cost required to cast Ramza is 0.'),
#  Document(metadata={'title': '22-067L - Nacht', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-067L - Nacht: - If you only search for 1 Job Warrior of Darkness, you can search without the limitation of names.'),
#  Document(metadata={'title': '22-032L - Sephiroth', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content="In reference to the card 22-032L - Sephiroth: - If the Forward chosen in the action ability becomes an unsuitable target before resolution, it is not possible to cast Sephiroth removed from the game.\n\n- If the action ability is used during the opponent's turn, you can cast Sephiroth on your next turn. If the action ability is used during your turn, you can cast Sephiroth on the same turn."),
#  Document(metadata={'title': '22-047L - Dorgann', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-047L - Dorgann: - The second effect can also be selected if Dorgann is the third card to be cast.'),
#  Document(metadata={'title': '22-044R - Cid (FFBE)', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-044R - Cid (FFBE): - CP is paid at resolution. After paying the cost, the auto-ability “play Cid (FFBE) from the Break Zone onto the field dull.” is placed on the stack.\n\n- If Cid (FFBE) leaves the Break Zone before the second auto-ability is resolved, Cid (FFBE) does not enter the field.'),
#  Document(metadata={'title': '22-004H - Angeal', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-004H - Angeal: - CP is paid at resolution. After paying the cost, the auto-ability “search for 1 Job SOLDIER Forward of cost X and play it onto the field.” is placed on the stack.'),
#  Document(metadata={'title': '22-040H - Enkidu', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-040H - Enkidu: - CP is paid at resolution. After paying the cost, the auto-ability “play Enkidu onto the field.” is placed on the stack.\n\n- If Enkidu leaves the Break Zone before the second auto-ability is resolved, Enkidu does not enter the field.'),
#  Document(metadata={'title': '22-024L - Kurasame', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-024L - Kurasame: - After selecting the first effect, even if the number of Ice Backups you control changes before resolution and becomes less than the number of characters you chose, you still Dull them.\n\n- The number of cards that your opponent discards by the second effect is decided at resolution. If the number of Ice Backups you control changes before resolution, the changed number is referenced.'),
#  Document(metadata={'title': '22-030C - Shinryu Celestia', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-030C - Shinryu Celestia: - Shinryu Celestia is also always [Card Name (Celestia)]. This also applies to when it is in the Break Zone, deck and hand.'),
#  Document(metadata={'title': '22-016H - Minwu (FFBE)', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-016H - Minwu (FFBE): - If the card chosen in the first action ability leaves the Break Zone before it is cast, it cannot be cast.\n\n- The first action ability can be used even if there are one or more cards in your hand.\n\n- The card chosen in the first action ability cannot be cast by discarding cards from your hand to generate CP. Your hand must have 0 cards at the time of declaring the cast.'),
#  Document(metadata={'title': '22-009H - Jecht', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-009H - Jecht: - If either Jecht or the chosen Forward leaves the field before the auto-ability is resolved, the Forward remaining in the field does not receive damage.'),
#  Document(metadata={'title': '22-005R - Ignacio', 'source': 'https://fftcg.square-enix-games.com/na/play-article/faq'}, page_content='In reference to the card 22-005R - Ignacio: - The cards from the deck are placed into the Break Zone at resolution. After placing the cards in the Break Zone, the auto-ability “choose up to 1 Forward. If all the cards put into the Break Zone are of Fire Element, deal it 9000 damage.” is placed on the stack.\n\n- Cards will be put into the Break Zone even if there are 2 or less cards left in the deck, however the subsequent auto-ability will not be triggered.')]

# %%
from langchain_ollama import OllamaEmbeddings

embedding = OllamaEmbeddings(model="mxbai-embed-large")

# %%
from langchain_chroma import Chroma

vectorstore = Chroma.from_documents(documents=docs, embedding=embedding)
vectorstore

# %%
# from langchain_qdrant import QdrantVectorStore
# from qdrant_client import QdrantClient
# from qdrant_client.http.models import Distance, VectorParams

# client = QdrantClient(":memory:")

# client.create_collection(
#     collection_name="demo_collection",
#     vectors_config=VectorParams(size=3072, distance=Distance.COSINE),
# )

# vectorstore = QdrantVectorStore(
#     client=client,
#     collection_name="demo_collection",
#     embedding=embedding,
# )
# vectorstore.add_documents(docs)
# vectorstore

# %%
# Retrieve and generate using the relevant snippets of the blog.
retriever = vectorstore.as_retriever(
    # search_type="mmr",
    # search_kwargs={'lambda_mult': 1.0}
    # search_type="similarity_score_threshold",
    # search_kwargs={'score_threshold': 0.35}
)
retriever
# Out:
# VectorStoreRetriever(tags=['Chroma', 'OllamaEmbeddings'], vectorstore=<langchain_chroma.vectorstores.Chroma object at 0x7f0f79c22a50>, search_kwargs={})

# %%
from langchain_ollama import OllamaLLM

# llm = OllamaLLM(model="qwen2.5:14b")
# llm = OllamaLLM(model="gemma2:27b", temperature=0.0)
llm = OllamaLLM(model="llama3.2")
# llm = OllamaLLM(model="phi3.5")

# %%
from langchain import hub
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

prompt = hub.pull("rlm/rag-prompt")

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)
# Out:
# /home/acbaraka/.cache/pypoetry/virtualenvs/crystalvision-4sHt3Jis-py3.11/lib/python3.11/site-packages/langsmith/client.py:323: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %%
rag_chain.invoke("Tell me about the crystals and the card 23-038H Lady Lilith")
# Out:
# "The crystal for card 23-038H Lady Lilith is paid at the point when effects are resolved, and after payment, her auto ability to select one Forward and gain control of it is added to the stack. The cost of using this special ability is not specified in the context provided. I don't know if there are any other costs associated with paying the crystal for Lady Lilith."

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

system_prompt = (
    "You are an assistant for question-answering tasks. "
    "Use the following pieces of retrieved context to answer "
    "the question. If you don't know the answer, say that you "
    "don't know. Use five sentences maximum and keep the "
    "answer concise. Be aware that same name can refer to multiple different cards."
    "\n\n"
    "{context}"
)

prompt2 = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

question_answer_chain = create_stuff_documents_chain(llm, prompt2)
rag_chain2 = create_retrieval_chain(retriever, question_answer_chain)

# %%
rag_chain2.invoke({"input": "Tell me about the crystals and the card 23-038H Lady Lilith"})
# Out:
# {'input': 'Tell me about the crystals and the card 23-038H Lady Lilith',
#  'context': [Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '[23-038H] Lady Lilith'}, page_content='In reference to the card [23-038H] Lady Lilith: The Crystal is paid at the point when effects are resolved. The auto ability to select one Forward and gain control of it is then added to the stack after payment is made.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '17-113L - Glaciela Wezette'}, page_content='In reference to the card 17-113L - Glaciela Wezette: You can use the special ability by paying 1 crystal instead of discarding a card of the same name. When doing so, you much pay other costs such as CP, etc.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '20-017R - Palom'}, page_content='In reference to the card 20-017R - Palom: - Crystals are paid at the point effects are resolved. The Auto-ability “Select one Forward and inflict 8000 damage on it” is added to the stack after paying,'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '15-035H - Setzer'}, page_content='In reference to the card 15-035H - Setzer: Crystal is paid at the point of resolution. After it is paid, the auto-ability “Reveal the top card of your deck. If it is a Character, you may play it onto the field.” goes onto the stack.')],
#  'answer': "The Crystal in reference to [23-038H] Lady Lilith: The Crystal is paid at the point when effects are resolved. This means that after Lady Lilith's effects are resolved, you pay the crystal cost. There is no specific mention of paying crystals before resolving effects, only after they are resolved. I couldn't find any information on how many crystals Lady Lilith requires to use her special ability or other abilities related to crystals and card effects."}

# %%
from langchain.chains import RetrievalQA

qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        retriever=retriever, chain_type="stuff",
        # chain_type_kwargs=chain_type_kwargs,
        return_source_documents=True)

# %%
qa_chain.invoke("Tell me about the crystals and the card 23-038H Lady Lilith")
# Out:
# {'query': 'Tell me about the crystals and the card 23-038H Lady Lilith',
#  'result': 'Based on the provided context, for the card [23-038H] Lady Lilith: The Crystal, payment of crystals is made at the point when effects are resolved. After payment is made, the auto ability to select one Forward and gain control of it is then added to the stack.',
#  'source_documents': [Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '[23-038H] Lady Lilith'}, page_content='In reference to the card [23-038H] Lady Lilith: The Crystal is paid at the point when effects are resolved. The auto ability to select one Forward and gain control of it is then added to the stack after payment is made.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '17-113L - Glaciela Wezette'}, page_content='In reference to the card 17-113L - Glaciela Wezette: You can use the special ability by paying 1 crystal instead of discarding a card of the same name. When doing so, you much pay other costs such as CP, etc.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '20-017R - Palom'}, page_content='In reference to the card 20-017R - Palom: - Crystals are paid at the point effects are resolved. The Auto-ability “Select one Forward and inflict 8000 damage on it” is added to the stack after paying,'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '15-035H - Setzer'}, page_content='In reference to the card 15-035H - Setzer: Crystal is paid at the point of resolution. After it is paid, the auto-ability “Reveal the top card of your deck. If it is a Character, you may play it onto the field.” goes onto the stack.')]}

# %%
qa_chain.invoke("Can I remove the Lightning element card discarded to pay the cost for Odin as part of its ability?")
# Out:
# {'query': 'Can I remove the Lightning element card discarded to pay the cost for Odin as part of its ability?',
#  'result': 'No, according to the context provided in reference to the card [23-080R] Odin, it is not possible to remove the Lightning element card discarded to pay the cost for this ability from the game.',
#  'source_documents': [Document(metadata={'source': 'https://fftcg.square-enix-games.com/en/play-article/faq', 'title': '[23-080R] Odin'}, page_content='In reference to the card [23-080R] Odin: It is not possible to remove the Lightning element card discarded to pay the cost for this ability from the game.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '18-024C - Shiva'}, page_content='In reference to the card 18-024C - Shiva: If the additional cost is paid when cast, 10 cards in the break zone are removed from the game at the same time the CP are paid.\n\nIt is not possible to pay the additional cost in situations where Shiva is cast without paying any cost in the first place, due to an effect of some kind.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '20-125R - Rosa'}, page_content="In reference to the card 20-125R - Rosa: - It is possible to pay for [20-075L] Cecil's option to activate his ability  using 《Earth》《Water》by paying 2CP of a preferred element."),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '8-035H - Squall'}, page_content="In reference to the card 8-035H - Squall: Unless there are 0 cards in your hand prior to paying the cost for Squall's action ability, it cannot be used. For example, if you have two cards in your hand and discard these in order to pay the cost, the ability cannot be used. (i.e the cost of this ability can only be paid with Backups)")]}

# %%
qa_chain.invoke("Can cards discarded to pay the cost for Odin as part of its ability?")
# Out:
# {'query': 'Can cards discarded to pay the cost for Odin as part of its ability?',
#  'result': "Based on the provided context, I don't know if cards discarded to pay the cost for Odin as part of its ability can be removed from the game. The first reference to Odin mentions that it is not possible to remove the Lightning element card discarded to pay the cost for this ability from the game, but it does not explicitly state whether other types of discarded cards are affected by this rule.",
#  'source_documents': [Document(metadata={'source': 'https://fftcg.square-enix-games.com/en/play-article/faq', 'title': '[23-080R] Odin'}, page_content='In reference to the card [23-080R] Odin: It is not possible to remove the Lightning element card discarded to pay the cost for this ability from the game.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '18-024C - Shiva'}, page_content='In reference to the card 18-024C - Shiva: If the additional cost is paid when cast, 10 cards in the break zone are removed from the game at the same time the CP are paid.\n\nIt is not possible to pay the additional cost in situations where Shiva is cast without paying any cost in the first place, due to an effect of some kind.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/en/play-article/faq', 'title': '[23-082H] King'}, page_content='In reference to the card [23-082H] King: - When using this ability, it is not possible to remove the character cards that were discarded to pay the cost for casting it.\n\n- This auto-ability causes cards to be discarded from the player’s hand at the point when effects are resolved. The auto ability to select one Forward and break it is then added to the stack after the cards are discarded.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '22-076R - Odin'}, page_content='In reference to the card 22-076R - Odin: - Only a card of cost 3 or 4 can be chosen for both Forward and Monster.')]}

# %%
qa_chain.invoke("Can play a 6th backup?")
# Out:
# {'query': 'Can play a 6th backup?',
#  'result': "According to the context, it appears that playing a 6th Backup is not possible when controlling exactly 5 Backups, because of card 17-128L - Maria. However, without more specific information about other cards or abilities that may affect this situation, I don't know for certain if there are any exceptions or alternative ways to play another Backup in this scenario.",
#  'source_documents': [Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': 'If I already control 5 Backups, how can I play another one onto the field?'}, page_content="In reference to the card If I already control 5 Backups, how can I play another one onto the field?: You can only have 5 Backups on your field at a given time but there are some abilities that can break Backups or return them to your hand in order to play different ones. Certain Backups like 1-120C Monk also need to be put into the Break Zone as part of their ability's cost so this is another way to free up some space on your field while using certain abilities."),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '17-128L - Maria'}, page_content='In reference to the card 17-128L - Maria: The chosen card is both a Forward and a Backup. Therefore, a Backup cannot be cast when five Backups are controlled, in which the chosen card is counted.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '9-062H - Vincent'}, page_content='In reference to the card 9-062H - Vincent: The Backup is put into the Break Zone at resolution. After that, the auto-ability “When you do so…” goes onto the stack and any other auto/action/special abilities can then be stacked in turn.'),
#   Document(metadata={'source': 'https://fftcg.square-enix-games.com/na/play-article/faq', 'title': '10-003C - Balasa'}, page_content='In reference to the card 10-003C - Balasa: The ability refers to the number of Backups you control at the time of resolution.')]}
